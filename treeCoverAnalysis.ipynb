# %%
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import re

# %%
df = pd.read_excel('./data/tree_cover/TreeCoverPune2009-2017.xls',  encoding = "utf-8")

# %%
df.set_index("Year").plot()
